# %% [markdown]
# # Item-Based Collaborative Filtering

# %% [markdown]
# As before, we'll start by importing the MovieLens 100K data set into a pandas DataFrame:

# %%
import pandas as pd

r_cols = ['user_id', 'movie_id', 'rating']
ratings = pd.read_csv('ml-100k/u.data', sep='\t', names=r_cols, usecols=range(3), encoding="ISO-8859-1")

m_cols = ['movie_id', 'title']
movies = pd.read_csv('ml-100k/u.item', sep='|', names=m_cols, usecols=range(2), encoding="ISO-8859-1")

ratings = pd.merge(movies, ratings)

movies.head()
# Out:
#    movie_id              title
# 0         1   Toy Story (1995)
# 1         2   GoldenEye (1995)
# 2         3  Four Rooms (1995)
# 3         4  Get Shorty (1995)
# 4         5     Copycat (1995)

# %% [markdown]
# Now we'll pivot this table to construct a nice matrix of users and the movies they rated. NaN indicates missing data, or movies that a given user did not watch:

# %%
userRatings = ratings.pivot_table(index=['user_id'],columns=['title'],values='rating')
userRatings.head(20)
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
# 6                              NaN           NaN                    NaN
# 7                              NaN           NaN                    NaN
# 8                              NaN           NaN                    NaN
# 9                              NaN           NaN                    NaN
# 10                             NaN           NaN                    NaN
# 11                             NaN           NaN                    NaN
# 12                             NaN           NaN                    NaN
# 13                             NaN           NaN                    2.0
# 14                             NaN           NaN                    NaN
# 15                             NaN           NaN                    3.0
# 16                             NaN           NaN                    NaN
# 17                             NaN           NaN                    NaN
# 18                             NaN           NaN                    NaN
# 19                             NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# 5                        NaN         NaN                          NaN
# 6                        4.0         NaN                          NaN
# 7                        4.0         NaN                          NaN
# 8                        NaN         NaN                          NaN
# 9                        NaN         NaN                          NaN
# 10                       5.0         NaN                          NaN
# 11                       NaN         NaN                          NaN
# 12                       NaN         NaN                          NaN
# 13                       4.0         NaN                          NaN
# 14                       NaN         NaN                          NaN
# 15                       NaN         NaN                          NaN
# 16                       5.0         NaN                          NaN
# 17                       NaN         NaN                          NaN
# 18                       3.0         NaN                          NaN
# 19                       NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# 0                                        NaN                           NaN
# 1                                        3.0                           4.0
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# 5                                        NaN                           4.0
# 6                                        NaN                           5.0
# 7                                        5.0                           5.0
# 8                                        NaN                           NaN
# 9                                        NaN                           NaN
# 10                                       NaN                           5.0
# 11                                       NaN                           4.0
# 12                                       NaN                           NaN
# 13                                       2.0                           5.0
# 14                                       NaN                           NaN
# 15                                       NaN                           NaN
# 16                                       NaN                           4.0
# 17                                       NaN                           NaN
# 18                                       NaN                           3.0
# 19                                       NaN                           NaN
#
# title    3 Ninjas: High Noon At Mega Mountain (1998)  39 Steps, The (1935)  \
# user_id
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                1.0                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
# 5                                                NaN                   NaN
# 6                                                NaN                   NaN
# 7                                                NaN                   4.0
# 8                                                NaN                   NaN
# 9                                                NaN                   4.0
# 10                                               NaN                   4.0
# 11                                               NaN                   NaN
# 12                                               NaN                   NaN
# 13                                               1.0                   4.0
# 14                                               NaN                   NaN
# 15                                               NaN                   NaN
# 16                                               NaN                   NaN
# 17                                               NaN                   NaN
# 18                                               NaN                   NaN
# 19                                               NaN                   NaN
#
# title    ...  Yankee Zulu (1994)  Year of the Horse (1997)  \
# user_id  ...
# 0        ...                 NaN                       NaN
# 1        ...                 NaN                       NaN
# 2        ...                 NaN                       NaN
# 3        ...                 NaN                       NaN
# 4        ...                 NaN                       NaN
# 5        ...                 NaN                       NaN
# 6        ...                 NaN                       NaN
# 7        ...                 NaN                       NaN
# 8        ...                 NaN                       NaN
# 9        ...                 NaN                       NaN
# 10       ...                 NaN                       NaN
# 11       ...                 NaN                       NaN
# 12       ...                 NaN                       NaN
# 13       ...                 NaN                       2.0
# 14       ...                 NaN                       NaN
# 15       ...                 NaN                       NaN
# 16       ...                 NaN                       NaN
# 17       ...                 NaN                       NaN
# 18       ...                 NaN                       NaN
# 19       ...                 NaN                       NaN
#
# title    You So Crazy (1994)  Young Frankenstein (1974)  Young Guns (1988)  \
# user_id
# 0                        NaN                        NaN                NaN
# 1                        NaN                        5.0                3.0
# 2                        NaN                        NaN                NaN
# 3                        NaN                        NaN                NaN
# 4                        NaN                        NaN                NaN
# 5                        NaN                        4.0                NaN
# 6                        NaN                        4.0                NaN
# 7                        NaN                        5.0                3.0
# 8                        NaN                        NaN                NaN
# 9                        NaN                        NaN                NaN
# 10                       NaN                        NaN                NaN
# 11                       NaN                        4.0                NaN
# 12                       NaN                        NaN                NaN
# 13                       NaN                        5.0                3.0
# 14                       NaN                        NaN                NaN
# 15                       NaN                        NaN                NaN
# 16                       NaN                        5.0                NaN
# 17                       NaN                        NaN                NaN
# 18                       NaN                        4.0                NaN
# 19                       NaN                        NaN                NaN
#
# title    Young Guns II (1990)  Young Poisoner's Handbook, The (1995)  \
# user_id
# 0                         NaN                                    NaN
# 1                         NaN                                    NaN
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
# 5                         NaN                                    NaN
# 6                         NaN                                    NaN
# 7                         NaN                                    3.0
# 8                         NaN                                    NaN
# 9                         NaN                                    NaN
# 10                        NaN                                    NaN
# 11                        NaN                                    NaN
# 12                        NaN                                    NaN
# 13                        NaN                                    1.0
# 14                        NaN                                    NaN
# 15                        NaN                                    NaN
# 16                        NaN                                    NaN
# 17                        NaN                                    NaN
# 18                        NaN                                    NaN
# 19                        NaN                                    NaN
#
# title    Zeus and Roxanne (1997)  unknown  Á köldum klaka (Cold Fever) (1994)
# user_id
# 0                            NaN      NaN                                 NaN
# 1                            NaN      4.0                                 NaN
# 2                            NaN      NaN                                 NaN
# 3                            NaN      NaN                                 NaN
# 4                            NaN      NaN                                 NaN
# 5                            NaN      4.0                                 NaN
# 6                            NaN      NaN                                 NaN
# 7                            NaN      NaN                                 NaN
# 8                            NaN      NaN                                 NaN
# 9                            NaN      NaN                                 NaN
# 10                           NaN      NaN                                 NaN
# 11                           NaN      NaN                                 NaN
# 12                           NaN      NaN                                 NaN
# 13                           NaN      NaN                                 NaN
# 14                           NaN      NaN                                 NaN
# 15                           NaN      NaN                                 NaN
# 16                           NaN      NaN                                 NaN
# 17                           NaN      NaN                                 NaN
# 18                           NaN      NaN                                 NaN
# 19                           NaN      NaN                                 NaN
#
# [20 rows x 1664 columns]

# %% [markdown]
# Now the magic happens - pandas has a built-in corr() method that will compute a correlation score for every column pair in the matrix! This gives us a correlation score between every pair of movies (where at least one user rated both movies - otherwise NaN's will show up.) That's amazing!

# %%
corrMatrix = userRatings.corr()
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        1.0           NaN
# 1-900 (1994)                                     NaN           1.0
# 101 Dalmatians (1996)                           -1.0           NaN
# 12 Angry Men (1957)                             -0.5           NaN
# 187 (1997)                                      -0.5           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)              -1.000000            -0.500000
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                   1.000000            -0.049890
# 12 Angry Men (1957)                    -0.049890             1.000000
# 187 (1997)                              0.269191             0.666667
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# 'Til There Was You (1997)   -0.500000                     0.522233
# 1-900 (1994)                      NaN                          NaN
# 101 Dalmatians (1996)        0.269191                     0.048973
# 12 Angry Men (1957)          0.666667                     0.256625
# 187 (1997)                   1.000000                     0.596644
#
# title                      20,000 Leagues Under the Sea (1954)  \
# title
# 'Til There Was You (1997)                                  NaN
# 1-900 (1994)                                               NaN
# 101 Dalmatians (1996)                                 0.266928
# 12 Angry Men (1957)                                   0.274772
# 187 (1997)                                                 NaN
#
# title                      2001: A Space Odyssey (1968)  \
# title
# 'Til There Was You (1997)                     -0.426401
# 1-900 (1994)                                  -0.981981
# 101 Dalmatians (1996)                         -0.043407
# 12 Angry Men (1957)                            0.178848
# 187 (1997)                                    -0.554700
#
# title                      3 Ninjas: High Noon At Mega Mountain (1998)  \
# title
# 'Til There Was You (1997)                                          NaN
# 1-900 (1994)                                                       NaN
# 101 Dalmatians (1996)                                              NaN
# 12 Angry Men (1957)                                                NaN
# 187 (1997)                                                         NaN
#
# title                      39 Steps, The (1935)  ...  Yankee Zulu (1994)  \
# title                                            ...
# 'Til There Was You (1997)                   NaN  ...                 NaN
# 1-900 (1994)                                NaN  ...                 NaN
# 101 Dalmatians (1996)                  0.111111  ...                 NaN
# 12 Angry Men (1957)                    0.457176  ...                 NaN
# 187 (1997)                             1.000000  ...                 NaN
#
# title                      Year of the Horse (1997)  You So Crazy (1994)  \
# title
# 'Til There Was You (1997)                       NaN                  NaN
# 1-900 (1994)                                    NaN                  NaN
# 101 Dalmatians (1996)                     -1.000000                  NaN
# 12 Angry Men (1957)                             NaN                  NaN
# 187 (1997)                                 0.866025                  NaN
#
# title                      Young Frankenstein (1974)  Young Guns (1988)  \
# title
# 'Til There Was You (1997)                        NaN                NaN
# 1-900 (1994)                               -0.944911                NaN
# 101 Dalmatians (1996)                       0.158840           0.119234
# 12 Angry Men (1957)                         0.096546           0.068944
# 187 (1997)                                  0.455233          -0.500000
#
# title                      Young Guns II (1990)  \
# title
# 'Til There Was You (1997)                   NaN
# 1-900 (1994)                                NaN
# 101 Dalmatians (1996)                  0.680414
# 12 Angry Men (1957)                   -0.361961
# 187 (1997)                             0.500000
#
# title                      Young Poisoner's Handbook, The (1995)  \
# title
# 'Til There Was You (1997)                                    NaN
# 1-900 (1994)                                                 NaN
# 101 Dalmatians (1996)                                   0.000000
# 12 Angry Men (1957)                                     0.144338
# 187 (1997)                                              0.475327
#
# title                      Zeus and Roxanne (1997)  unknown  \
# title
# 'Til There Was You (1997)                      NaN      NaN
# 1-900 (1994)                                   NaN      NaN
# 101 Dalmatians (1996)                     0.707107      NaN
# 12 Angry Men (1957)                       1.000000      1.0
# 187 (1997)                                     NaN      NaN
#
# title                      Á köldum klaka (Cold Fever) (1994)
# title
# 'Til There Was You (1997)                                 NaN
# 1-900 (1994)                                              NaN
# 101 Dalmatians (1996)                                     NaN
# 12 Angry Men (1957)                                       NaN
# 187 (1997)                                                NaN
#
# [5 rows x 1664 columns]

# %% [markdown]
# However, we want to avoid spurious results that happened from just a handful of users that happened to rate the same pair of movies. In order to restrict our results to movies that lots of people rated together - and also give us more popular results that are more easily recongnizable - we'll use the min_periods argument to throw out results where fewer than 100 users rated a given movie pair:

# %%
corrMatrix = userRatings.corr(method='pearson', min_periods=100)
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        NaN           NaN
# 1-900 (1994)                                     NaN           NaN
# 101 Dalmatians (1996)                            NaN           NaN
# 12 Angry Men (1957)                              NaN           NaN
# 187 (1997)                                       NaN           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)                    NaN                  NaN
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                        1.0                  NaN
# 12 Angry Men (1957)                          NaN                  1.0
# 187 (1997)                                   NaN                  NaN
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# 'Til There Was You (1997)         NaN                          NaN
# 1-900 (1994)                      NaN                          NaN
# 101 Dalmatians (1996)             NaN                          NaN
# 12 Angry Men (1957)               NaN                          NaN
# 187 (1997)                        NaN                          NaN
#
# title                      20,000 Leagues Under the Sea (1954)  \
# title
# 'Til There Was You (1997)                                  NaN
# 1-900 (1994)                                               NaN
# 101 Dalmatians (1996)                                      NaN
# 12 Angry Men (1957)                                        NaN
# 187 (1997)                                                 NaN
#
# title                      2001: A Space Odyssey (1968)  \
# title
# 'Til There Was You (1997)                           NaN
# 1-900 (1994)                                        NaN
# 101 Dalmatians (1996)                               NaN
# 12 Angry Men (1957)                                 NaN
# 187 (1997)                                          NaN
#
# title                      3 Ninjas: High Noon At Mega Mountain (1998)  \
# title
# 'Til There Was You (1997)                                          NaN
# 1-900 (1994)                                                       NaN
# 101 Dalmatians (1996)                                              NaN
# 12 Angry Men (1957)                                                NaN
# 187 (1997)                                                         NaN
#
# title                      39 Steps, The (1935)  ...  Yankee Zulu (1994)  \
# title                                            ...
# 'Til There Was You (1997)                   NaN  ...                 NaN
# 1-900 (1994)                                NaN  ...                 NaN
# 101 Dalmatians (1996)                       NaN  ...                 NaN
# 12 Angry Men (1957)                         NaN  ...                 NaN
# 187 (1997)                                  NaN  ...                 NaN
#
# title                      Year of the Horse (1997)  You So Crazy (1994)  \
# title
# 'Til There Was You (1997)                       NaN                  NaN
# 1-900 (1994)                                    NaN                  NaN
# 101 Dalmatians (1996)                           NaN                  NaN
# 12 Angry Men (1957)                             NaN                  NaN
# 187 (1997)                                      NaN                  NaN
#
# title                      Young Frankenstein (1974)  Young Guns (1988)  \
# title
# 'Til There Was You (1997)                        NaN                NaN
# 1-900 (1994)                                     NaN                NaN
# 101 Dalmatians (1996)                            NaN                NaN
# 12 Angry Men (1957)                              NaN                NaN
# 187 (1997)                                       NaN                NaN
#
# title                      Young Guns II (1990)  \
# title
# 'Til There Was You (1997)                   NaN
# 1-900 (1994)                                NaN
# 101 Dalmatians (1996)                       NaN
# 12 Angry Men (1957)                         NaN
# 187 (1997)                                  NaN
#
# title                      Young Poisoner's Handbook, The (1995)  \
# title
# 'Til There Was You (1997)                                    NaN
# 1-900 (1994)                                                 NaN
# 101 Dalmatians (1996)                                        NaN
# 12 Angry Men (1957)                                          NaN
# 187 (1997)                                                   NaN
#
# title                      Zeus and Roxanne (1997)  unknown  \
# title
# 'Til There Was You (1997)                      NaN      NaN
# 1-900 (1994)                                   NaN      NaN
# 101 Dalmatians (1996)                          NaN      NaN
# 12 Angry Men (1957)                            NaN      NaN
# 187 (1997)                                     NaN      NaN
#
# title                      Á köldum klaka (Cold Fever) (1994)
# title
# 'Til There Was You (1997)                                 NaN
# 1-900 (1994)                                              NaN
# 101 Dalmatians (1996)                                     NaN
# 12 Angry Men (1957)                                       NaN
# 187 (1997)                                                NaN
#
# [5 rows x 1664 columns]

# %% [markdown]
# Now let's produce some movie recommendations for user ID 0, who I manually added to the data set as a test case. This guy really likes Star Wars and The Empire Strikes Back, but hated Gone with the Wind. I'll extract his ratings from the userRatings DataFrame, and use dropna() to get rid of missing data (leaving me only with a Series of the movies I actually rated:)

# %%
myRatings = userRatings.loc[0].dropna()
myRatings
# Out:
# title
# Empire Strikes Back, The (1980)    5.0
# Gone with the Wind (1939)          1.0
# Star Wars (1977)                   5.0
# Name: 0, dtype: float64

# %%
corrMatrix2 = corrMatrix
corrMatrix3 = corrMatrix2.loc[["Empire Strikes Back, The (1980)","Gone with the Wind (1939)","Star Wars (1977)"]]
corrMatrix3
# Out:
# title                            'Til There Was You (1997)  1-900 (1994)  \
# title
# Empire Strikes Back, The (1980)                        NaN           NaN
# Gone with the Wind (1939)                              NaN           NaN
# Star Wars (1977)                                       NaN           NaN
#
# title                            101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# Empire Strikes Back, The (1980)                    NaN                  NaN
# Gone with the Wind (1939)                          NaN                  NaN
# Star Wars (1977)                                   NaN             0.184289
#
# title                            187 (1997)  2 Days in the Valley (1996)  \
# title
# Empire Strikes Back, The (1980)         NaN                          NaN
# Gone with the Wind (1939)               NaN                          NaN
# Star Wars (1977)                        NaN                          NaN
#
# title                            20,000 Leagues Under the Sea (1954)  \
# title
# Empire Strikes Back, The (1980)                                  NaN
# Gone with the Wind (1939)                                        NaN
# Star Wars (1977)                                                 NaN
#
# title                            2001: A Space Odyssey (1968)  \
# title
# Empire Strikes Back, The (1980)                      0.141598
# Gone with the Wind (1939)                            0.004890
# Star Wars (1977)                                     0.230884
#
# title                            3 Ninjas: High Noon At Mega Mountain (1998)  \
# title
# Empire Strikes Back, The (1980)                                          NaN
# Gone with the Wind (1939)                                                NaN
# Star Wars (1977)                                                         NaN
#
# title                            39 Steps, The (1935)  ...  \
# title                                                  ...
# Empire Strikes Back, The (1980)                   NaN  ...
# Gone with the Wind (1939)                         NaN  ...
# Star Wars (1977)                                  NaN  ...
#
# title                            Yankee Zulu (1994)  Year of the Horse (1997)  \
# title
# Empire Strikes Back, The (1980)                 NaN                       NaN
# Gone with the Wind (1939)                       NaN                       NaN
# Star Wars (1977)                                NaN                       NaN
#
# title                            You So Crazy (1994)  \
# title
# Empire Strikes Back, The (1980)                  NaN
# Gone with the Wind (1939)                        NaN
# Star Wars (1977)                                 NaN
#
# title                            Young Frankenstein (1974)  Young Guns (1988)  \
# title
# Empire Strikes Back, The (1980)                   0.185887                NaN
# Gone with the Wind (1939)                              NaN                NaN
# Star Wars (1977)                                  0.192589                NaN
#
# title                            Young Guns II (1990)  \
# title
# Empire Strikes Back, The (1980)                   NaN
# Gone with the Wind (1939)                         NaN
# Star Wars (1977)                                  NaN
#
# title                            Young Poisoner's Handbook, The (1995)  \
# title
# Empire Strikes Back, The (1980)                                    NaN
# Gone with the Wind (1939)                                          NaN
# Star Wars (1977)                                                   NaN
#
# title                            Zeus and Roxanne (1997)  unknown  \
# title
# Empire Strikes Back, The (1980)                      NaN      NaN
# Gone with the Wind (1939)                            NaN      NaN
# Star Wars (1977)                                     NaN      NaN
#
# title                            Á köldum klaka (Cold Fever) (1994)
# title
# Empire Strikes Back, The (1980)                                 NaN
# Gone with the Wind (1939)                                       NaN
# Star Wars (1977)                                                NaN
#
# [3 rows x 1664 columns]

# %%
"""We want to pullout the movies in corrMatrix that are highly correlated thus similar to the ones with high ratings 
in the user's seen movie list. If the movie is the same as the as watched then don't recommend."""
# Consider adding movies with low ratings to the list
recommend = [] # stores the movies to be recommended
threshold = (5-1)/5   # qualifying correlation level for a movie to be selected
watched = ["Empire Strikes Back, The (1980)","Gone with the Wind (1939)","Star Wars (1977)"]
corrMatrix2 = corrMatrix.loc[["Empire Strikes Back, The (1980)","Gone with the Wind (1939)","Star Wars (1977)"]]
columns = corrMatrix2.shape[1] # No of columns in corrMatrix
movieNameList = list(corrMatrix2.columns.values)
for movie in range(len(watched)): 
    print("movie = ",movie)
    for j in range(columns):
        if str(corrMatrix2.iat[movie,j]) != 'NaN':
            if corrMatrix2.iat[movie,j] > threshold and corrMatrix2.iat[movie,j] < 0.9999:
                recommend.append(movieNameList[j])
recommend
# Out:
# movie =  0
# movie =  1
# movie =  2
# []

# %% [markdown]
# Now, let's go through each movie User0 rated one at a time, and build up a list of possible recommendations based on the movies similar to the ones the user rated.
#
# So for each movie he rated, I'll retrieve the list of similar movies from our correlation matrix. I'll then scale those correlation scores by how well I rated the movie they are similar to, so movies similar to ones he liked count more than movies similar to ones he hated:

# %%
simCandidates = pd.Series()
for i in range(0, len(myRatings.index)):
    print ("Adding sims for " + myRatings.index[i] + "...")
    # Retrieve similar movies to this one that I rated
    sims = corrMatrix[myRatings.index[i]].dropna()
    # Now scale its similarity by how well I rated this movie
    sims = sims.map(lambda x: x * myRatings[i])
    # Add the score to the list of similarity candidates
    simCandidates = simCandidates.append(sims)
    
#Glance at our results so far:
print ("sorting...")
simCandidates.sort_values(inplace = True, ascending = False)
print (simCandidates.head(10))
# Out:
# Adding sims for Empire Strikes Back, The (1980)...
# Adding sims for Gone with the Wind (1939)...
# Adding sims for Star Wars (1977)...
# sorting...
# Empire Strikes Back, The (1980)                       5.000000
# Star Wars (1977)                                      5.000000
# Empire Strikes Back, The (1980)                       3.741763
# Star Wars (1977)                                      3.741763
# Return of the Jedi (1983)                             3.606146
# Return of the Jedi (1983)                             3.362779
# Raiders of the Lost Ark (1981)                        2.693297
# Raiders of the Lost Ark (1981)                        2.680586
# Austin Powers: International Man of Mystery (1997)    1.887164
# Sting, The (1973)                                     1.837692
# dtype: float64

# %% [markdown]
# This is starting to look like something useful! Note that some of the same movies came up more than once, because they were similar to more than one movie I rated. We'll use groupby() to add together the scores from movies that show up more than once, so they'll count more:

# %%
simCandidates = simCandidates.groupby(simCandidates.index).sum()

# %%
simCandidates.sort_values(inplace = True, ascending = False)
simCandidates.head(10)
# Out:
# Empire Strikes Back, The (1980)              8.877450
# Star Wars (1977)                             8.870971
# Return of the Jedi (1983)                    7.178172
# Raiders of the Lost Ark (1981)               5.519700
# Indiana Jones and the Last Crusade (1989)    3.488028
# Bridge on the River Kwai, The (1957)         3.366616
# Back to the Future (1985)                    3.357941
# Sting, The (1973)                            3.329843
# Cinderella (1950)                            3.245412
# Field of Dreams (1989)                       3.222311
# dtype: float64

# %% [markdown]
# The last thing we have to do is filter out movies I've already rated, as recommending a movie I've already watched isn't helpful:

# %% [raw]
# filteredSims = simCandidates.drop(myRatings.index)
# filteredSims.head(10)

# %% [markdown]
# There we have it!

# %% [markdown]
# ## Exercise

# %% [markdown]
# Can you improve on these results? Perhaps a different method or min_periods value on the correlation computation would produce more interesting results.
#
# Also, it looks like some movies similar to Gone with the Wind - which I hated - made it through to the final list of recommendations. Perhaps movies similar to ones the user rated poorly should actually be penalized, instead of just scaled down?
#
# There are also probably some outliers in the user rating data set - some users may have rated a huge amount of movies and have a disporportionate effect on the results. Go back to earlier lectures to learn how to identify these outliers, and see if removing them improves things.
#
# For an even bigger project: we're evaluating the result qualitatively here, but we could actually apply train/test and measure our ability to predict user ratings for movies they've already watched. Whether that's actually a measure of a "good" recommendation is debatable, though!
